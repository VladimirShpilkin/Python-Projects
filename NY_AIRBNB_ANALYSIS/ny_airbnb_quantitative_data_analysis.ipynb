# %%
#1 Change the directory
import os
new_directory = r'C:\Users\vladimir.shpilkin\Desktop\Learning\Python-Projects\NY_AIRBNB_QUANTITATIVE_DATA_ANALYSIS'
os.chdir(new_directory)

print("Current Directory" , os.getcwd())
# Out:
# Current Directory c:\Users\vladimir.shpilkin\Desktop\Learning\Python-Projects\NY_AIRBNB_QUANTITATIVE_DATA_ANALYSIS

# %%
#3 Import pandas, matplotlib, seaborn,numpy and missingo libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import numpy as np
import missingno as msno

# %%
#2 create the file path
csv_file_path='AB_NYC_2019.csv'
bnb=pd.read_csv(csv_file_path)

# %%
#create the DataFrame object
df=pd.DataFrame(bnb)

# %%
#inspect the data and inconsistencies
msno.matrix(df)
plt.xticks(range(len(df.columns)),rotation=45)
plt.show()

# %%
#creating the histogram of the price column
plt.hist(bnb['price']) #column for this historical data
plt.xlabel('price in USD') #naming the x axis
plt.show()

# %%
#creating the histogram by the price column
plt.hist(bnb['price'],bins=np.arange(0,1100,10)) #column for this historical data, creating the bin and assigning the left and right ends of the x axis and the step size
plt.xlabel('price in USD') #naming the x axis
plt.show()

# %%
from importlib import reload
plt=reload(plt)

# %%
plt.scatter(x=bnb['price'],y=bnb['number_of_reviews'])
plt.xlabel('Price')#set the x axis naming
plt.ylabel('Reviews')#set the y axis naming
plt.xlim(0,1100)#set the x axis limit
plt.ylim(0,700)#set the y axis limit
plt.show()

# %%
plt.scatter(x=bnb['price'],y=bnb['number_of_reviews'],s=2,c='#00b5e2')
plt.xlabel('Price')#set the x axis naming
plt.ylabel('Reviews')#set the y axis naming
plt.xlim(0,1100)#set the x axis limit
plt.ylim(0,700)#set the y axis limit
color='#00b5e2'
plt.show()
