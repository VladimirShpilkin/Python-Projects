# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings
import missingno as msno

# %%
#change the directory to the original file location
new_directory=r'C:\Users\vladimir.shpilkin\Desktop\Learning\Python-Projects\food_choices'
os.chdir(new_directory)
print('New directory is',os.getcwd())
# Out:
# New directory is c:\Users\vladimir.shpilkin\Desktop\Learning\Python-Projects\food_choices

# %%
#convert the data to the dataframe object
df=pd.read_csv('food_coded.csv')
#check the data types
print(df.dtypes)
#check the dataframe size/shape
print(df.shape)
# Out:
# GPA                  object
# Gender                int64
# breakfast             int64
# calories_chicken      int64
# calories_day        float64
#                      ...
# type_sports          object
# veggies_day           int64
# vitamins              int64
# waffle_calories       int64
# weight               object
# Length: 61, dtype: object
# (125, 61)

# %%
#finding the numeric columns and their count

df_numeric=df.select_dtypes(include=[np.number])
df_numeric_columns=df_numeric.columns.values
df_numeric_columns.size
# Out:
# 47

# %%
#finding the non-numeric columns and their count
df_other=df.select_dtypes(exclude=[np.number])
df_other_columns=df_other.columns.values
df_other_columns.size
# Out:
# 14

# %%
df
# Out:
#        GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0      2.4       2          1               430           NaN           315.0
# 1    3.654       1          1               610           3.0           420.0
# 2      3.3       1          1               720           4.0           420.0
# 3      3.2       1          1               430           3.0           420.0
# 4      3.5       1          1               720           2.0           420.0
# ..     ...     ...        ...               ...           ...             ...
# 120    3.5       1          1               610           4.0           420.0
# 121      3       1          1               265           2.0           315.0
# 122  3.882       1          1               720           NaN           420.0
# 123      3       2          1               720           4.0           420.0
# 124    3.9       1          1               430           NaN           315.0
#
# ...

# %%
#identify the missing values in the dataset

msno.matrix(df)
plt.xticks(range(len(df.columns)), df.columns, rotation=90,size=20)
plt.show()

# %% [markdown]
# <div style="display: flex; justify-content: center; align-items: center; height: 100%;">
#     <span style="color: black; font-family: 'Times New Roman'; font-size: 30px;">
#         Identify if the fruits and vegetables consumption affect the GPA
#     </span>
# </div>

# %%
df_gpa=df[['GPA','fruit_day','veggies_day']]

# %%
#nan distribution
msno.matrix(df_gpa[df_gpa.columns[df_gpa.isnull().any()]])
# Out:
# <Axes: >
